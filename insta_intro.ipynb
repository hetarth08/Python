# %%
print("Name:Hetarth Sukhadiya")
print("Favoraite App:Moctale")
# Out:
# Name:Hetarth Sukhadiya
# Favoraite App:Moctale

# %%
print("Welcome to Data Science with Python")
# Out:
# Welcome to Data Science with Python
